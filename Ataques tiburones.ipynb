# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import regex as re
import pylab as plt

import src
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Load data from attacks.csv

data = pd.read_csv('attacks.csv', encoding='ISO-8859-1')

# %%
# Revisamos datos e info

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51448 entries, 0 to 51447
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             17406 non-null  object
#  1   Date                    12605 non-null  object
#  2   Year                    12601 non-null  object
#  3   Type                    12597 non-null  object
#  4   Country                 12505 non-null  object
#  5   Area                    11695 non-null  object
#  6   Location                11525 non-null  object
#  7   Activity                11517 non-null  object
#  8   Name                    12185 non-null  object
#  9   Sex                     11475 non-null  object
#  10  Age                     6943 non-null   object
#  11  Injury                  12549 non-null  object
#  12  Fatal (Y/N)             11527 non-null  object
#  13  Time                    5897 non-null   object
# ...

# %%
# Vemos el número de filas y columnas

data.shape
# Out:
# (51448, 24)

# %% [markdown]
# ## Limpieza de nulos

# %%
# Quitamos las filas de valores nulos

data.dropna(how = "all", inplace = True)
data.tail(10)
# Out:
#       Case Number Date Year Type Country Area Location Activity Name Sex   \
# 34418           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34419           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34420           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34421           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34422           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34423           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34424           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34425           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 34426           0  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 51447          xx  NaN  NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N) Time Species  Investigator or Source  pdf  \
# 34418  NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# ...

# %%
data.shape
# Out:
# (17408, 24)

# %%
data.isnull().sum().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Eliminar duplicados

# %%
# Eliminamos filas duplicadas

data=data.drop_duplicates()
data.drop_duplicates(inplace=True)

# %%
# Comprobamos que no hay más duplicados.

data.duplicated().any()
# Out:
# False

# %%
data.shape
# Out:
# (6313, 24)

# %%
data.tail(20)
# Out:
#        Case Number         Date  Year        Type             Country  \
# 6293       ND.0009  Before 1906  0000  Unprovoked           AUSTRALIA
# 6294       ND.0008  Before 1906  0000  Unprovoked           AUSTRALIA
# 6295       ND.0007  Before 1906  0000  Unprovoked           AUSTRALIA
# 6296       ND.0006  Before 1906  0000  Unprovoked           AUSTRALIA
# 6297       ND.0005  Before 1903  0000  Unprovoked           AUSTRALIA
# 6298       ND.0004  Before 1903  0000  Unprovoked           AUSTRALIA
# 6299       ND.0003    1900-1905  0000  Unprovoked                 USA
# 6300       ND.0002    1883-1889  0000  Unprovoked              PANAMA
# 6301       ND.0001    1845-1853  0000  Unprovoked  CEYLON (SRI LANKA)
# 6302             0          NaN   NaN         NaN                 NaN
# 6303             0          NaN   NaN         NaN                 NaN
# 6304             0          NaN   NaN         NaN                 NaN
# ...

# %%
data.drop([6302, 6303, 6304, 6305, 6306, 6307, 6308, 6309, 25722, 25723, 25724], axis=0, inplace=True)
data
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  0000  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  0000  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  0000  Unprovoked                 USA
# 6300     ND.0002    1883-1889  0000  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  0000  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
data.shape
# Out:
# (6302, 24)

# %%
data.isnull().sum().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Species '].value_counts()
# Out:
# White shark                                                                                                                      163
# Shark involvement prior to death was not confirmed                                                                               105
# Invalid                                                                                                                          102
# Shark involvement not confirmed                                                                                                   88
# Tiger shark                                                                                                                       73
#                                                                                                                                 ...
# 1.2 m to 1.5 m [4.5' to 5'] shark                                                                                                  1
# ...

# %%
data['Species '].unique()
# Out:
# array(['White shark', nan, '2 m shark', ..., "12' tiger shark",
#        'Blue pointers',
#        'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable'],
#       dtype=object)

# %%
# Aquí vemos todos tipos de tiburones 
# data['Species '].unique().tolist()

# %%
# el pais con más índice de ataques es USA

# %%
data_usa=data[data['Country'] == 'USA']

# %%
data_usa.head()
# Out:
#     Case Number         Date  Year        Type Country        Area  \
# 0    2018.06.25  25-Jun-2018  2018     Boating     USA  California
# 1    2018.06.18  18-Jun-2018  2018  Unprovoked     USA     Georgia
# 2    2018.06.09  09-Jun-2018  2018     Invalid     USA      Hawaii
# 7    2018.05.27  27-May-2018  2018  Unprovoked     USA     Florida
# 8  2018.05.26.b  26-May-2018  2018  Unprovoked     USA     Florida
#
#                                             Location  Activity  \
# 0                        Oceanside, San Diego County  Paddling
# 1                     St. Simon Island, Glynn County  Standing
# 2                                       Habush, Oahu   Surfing
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing
# 8                       Cocoa Beach, Brevard  County   Walking
#
#               Name Sex  Age  \
# 0      Julie Wolfe    F  57
# 1  Adyson McNeely     F  11
# 2      John Denges    M  48
# 7             male    M  52
# 8        Cody High    M  15
#
# ...

# %%
data_usa.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Aquí podemos ver los nulos por columnas

data_final.isnull().sum().sort_values()
# Out:
# Date             0
# Year             0
# Type             0
# Country          0
# Area             4
# Sex             98
# Activity       134
# Fatal (Y/N)    188
# Age            727
# dtype: int64

# %%
data['Age'] = data['Age'].apply(src.value_to_num)

# %%
data['Age'].value_counts()
# Out:
# 17         156
# 18         153
# 20         150
# 19         142
# 16         139
#           ...
# Teens        1
#  30          1
# mid-30s      1
# 6½           1
# 2½           1
# Name: Age, Length: 112, dtype: int64

# %% [markdown]
# ## Conversión

# %%
# Limpiamos fechas de posibles datos que no esten corrrectamente uniformados o sobren
data_final['Date'] = data_final['Date'].apply(lambda x: re.sub('Before' and 'Reported' , '', x))
data_final['Date'] = data_final['Date'].apply(lambda x: re.sub(' ' , '', x))
data_final['Date'].head(60)
# Out:
# 0     25-Jun-2018
# 1     18-Jun-2018
# 2     09-Jun-2018
# 3     27-May-2018
# 4     26-May-2018
# 5     26-May-2018
# 6     21-May-2018
# 7     13-May-2018
# 8     19-Apr-2018
# 9     31-Mar-2018
# 10    31-Dec-2017
# 11    30-Dec-2017
# 12    24-Nov-2017
# 13    18-Nov-2017
# 14    26-Oct-2017
# 15    23-Oct-2017
# 16    23-Oct-2017
# 17    18-Oct-2017
# 18    09-Oct-2017
# 19    05-Oct-2017
# 20    25-Sep-2017
# 21    24-Sep-2017
# 22    24-Sep-2017
# 23    20-Sep-2017
# 24    16-Sep-2017
# 25    13-Sep-2017
# 26    02-Sep-2017
# 27    02-Sep-2017
# 28    02-Sep-2017
# 29    27-Aug-2017
# 30    23-Aug-2017
# 31    10-Aug-2017
# 32    03-Aug-2017
# 33    01-Aug-2017
# 34    31-Jul-2017
# 35    29-Jul-2017
# 36    29-Jul-2017
# 37    23-Jul-2017
# 38    22-Jul-2017
# 39    20-Jul-2017
# 40    20-Jul-2017
# 41    20-Jul-2017
# 42    14-Jul-2017
# 43    11-Jul-2017
# 44    09-Jul-2017
# 45    29-Jun-2017
# 46    21-Jun-2017
# 47    19-Jun-2017
# 48    18-Jun-2017
# 49    10-Jun-2017
# ...

# %%
data_final.info()
data_final.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2229 entries, 0 to 2228
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2229 non-null   object
#  1   Year         2229 non-null   object
#  2   Type         2229 non-null   object
#  3   Country      2229 non-null   object
#  4   Area         2225 non-null   object
#  5   Activity     2095 non-null   object
#  6   Sex          2131 non-null   object
#  7   Age          1502 non-null   object
#  8   Fatal (Y/N)  2041 non-null   object
# dtypes: object(9)
# memory usage: 156.9+ KB
# Date             0
# Year             0
# Type             0
# Country          0
# Area             4
# Activity       134
# Sex             98
# Age            727
# Fatal (Y/N)    188
# dtype: int64

# %%
data.shape
# Out:
# (6302, 24)

# %%
data.to_csv('../attacks.csv')
